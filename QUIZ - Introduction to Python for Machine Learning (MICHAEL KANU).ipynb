# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df[(df['Area'] == 'Madagascar') & (df['Element'] == 'Protein supply quantity (g/capita/day)')]
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
# ...          ...         ...        ...                       ...
# 32113        129  Madagascar       2769   Aquatic Animals, Others
# 32123        129  Madagascar       2775            Aquatic Plants
# 32133        129  Madagascar       2928             Miscellaneous
# 32142        129  Madagascar       2680               Infant food
# 32152        129  Madagascar       2899             Miscellaneous
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# ...

# %%
import pandas as pd

# Select the columns of interest
columns_of_interest = ['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']

# Calculate the correlation matrix
correlation_matrix = df[columns_of_interest].corr()

# Exclude the 'Element Code' row since we are interested in its correlation with years
element_code_correlation = correlation_matrix.loc['Element Code']

# Find the year with the minimum correlation with 'Element Code'
least_correlated_year = element_code_correlation.idxmin()

print("Year with the least correlation with 'Element Code':", least_correlated_year)
print("Correlation coefficient:", element_code_correlation[least_correlated_year])
# Out:
# Year with the least correlation with 'Element Code': Y2016
# Correlation coefficient: 0.02344399758496104

# %%
import pandas as pd

# Select columns 'Y2017' and 'Area'
selected_columns = ['Area', 'Y2017']
selected_data = df[selected_columns]

# Group by 'Area' and calculate the sum of 'Y2017' for each area
sum_by_area = selected_data.groupby('Area')['Y2017'].sum()

# Find the area with the highest sum
area_with_highest_sum = sum_by_area.idxmax()
highest_sum = sum_by_area.max()

print("Area with the highest sum in 2017:", area_with_highest_sum)
print("Sum in 2017:", highest_sum)
# Out:
# Area with the highest sum in 2017: Nigeria
# Sum in 2017: 1483268.23

# %%
import pandas as pd

# Select columns 'Element' and 'Y2017'
selected_columns = ['Element', 'Y2017']
selected_data = df[selected_columns]

# Filter the data to include only rows where the 'Element' is 'Processing'
processing_data = selected_data[selected_data['Element'] == 'Processing']

# Group by 'Element' and calculate the sum of 'Y2017' for the 'Processing' element
sum_processing_2017 = processing_data.groupby('Element')['Y2017'].sum()

print("Total sum of Processing in 2017:", sum_processing_2017.values[0])
# Out:
# Total sum of Processing in 2017: 292836.0

# %%
#Check for the number of rows and columns in a pandas DataFrame named df

df.shape
# Out:
# (60943, 12)

# %%
# Group by 'Element' and sum the values for each year

df.groupby('Element').sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23996\3319754548.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
# Group by 'Area' and sum the 'Y2017' values
grouped = df.groupby('Area')['Y2017'].sum()

# Sort the sums in ascending order
sorted_sums = grouped.sort_values()

# Get the 7th element (indexing starts from 0)
seventh_lowest_area = sorted_sums.index[6]

print("Area with the 7th lowest sum in 2017:", seventh_lowest_area)
# Out:
# Area with the 7th lowest sum in 2017: Guinea-Bissau

# %%
df.iloc[ : ]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Calculate the mean for the year 2017
mean_2017 = df['Y2017'].mean()

# Calculate the standard deviation for the year 2017
std_2017 = df['Y2017'].std()

print("Mean for the year 2017:", round(mean_2017, 2))
print("Standard deviation for the year 2017:", round(std_2017, 2))
# Out:
# Mean for the year 2017: 140.92
# Standard deviation for the year 2017: 1671.86

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
# Total number of missing values in 2014
missing_values_2014 = df['Y2014'].isnull().sum()

# Total number of entries in 2014
total_entries_2014 = df['Y2014'].shape[0]

# Percentage of missing values in 2014
percentage_missing_2014 = (missing_values_2014 / total_entries_2014) * 100

# Round to 3 decimal places
percentage_missing_2014 = round(percentage_missing_2014, 3)

print("Total number of missing values in 2014:", missing_values_2014)
print("Percentage of missing values in 2014:", percentage_missing_2014)
# Out:
# Total number of missing values in 2014: 1589
# Percentage of missing values in 2014: 2.607

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Group by 'Item' and sum the values for 'Wine' in 2015
wine_2015_sum = df.groupby('Item')['Y2015'].sum()

# Group by 'Item' and sum the values for 'Wine' in 2018
wine_2018_sum = df.groupby('Item')['Y2018'].sum()

print("Total sum of Wine produced in 2015:", wine_2015_sum)
print('\n')
print("Total sum of Wine produced in 2018:", wine_2018_sum)
# Out:
# Total sum of Wine produced in 2015: Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64
#
#
# Total sum of Wine produced in 2018: Item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: Y2018, Length: 119, dtype: float64

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 3
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
col = ['Age', 'Nationality', 'Overall']
       
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

df2 = pd.DataFrame(lst, columns = col, index = [1,2,3])

df2
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][1]
x
# Out:
# 8
